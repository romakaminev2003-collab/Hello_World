# %% [markdown]
# <a href="https://colab.research.google.com/github/romakaminev2003-collab/Hello_World/blob/main/%D0%9F%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D1%87%D0%B5%D1%81%D0%BA%D0%BE%D0%B5_%D0%B7%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D0%B5_12_4%2C_12_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.metrics import recall_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
import pandas as pd
from sklearn.preprocessing import LabelEncoder


def table_preprocessing(file_name):
    df = pd.read_csv(file_name)
    df.drop ('Booking_ID', axis = 1, inplace=True)

    labelencoder = LabelEncoder()
    df['type_of_meal_plan'] = labelencoder.fit_transform(df['type_of_meal_plan'])
    df['room_type_reserved'] = labelencoder.fit_transform(df['room_type_reserved'])
    df['market_segment_type'] = labelencoder.fit_transform(df['market_segment_type'])
    df['booking_status'] = labelencoder.fit_transform(df['booking_status'])

    x = df.drop('booking_status', axis = 1)
    y = df['booking_status']

    return x, y

def hotel_booking_analyze (x, y):
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25)

    svc = SVC()
    svc.fit(x_train, y_train)
    y_svc_pred = svc.predict(x_test)

    k_nbrs = KNeighborsClassifier(n_neighbors=5)
    k_nbrs.fit(x_train, y_train)
    y_knbrs_pred = k_nbrs.predict(x_test)

    clf_tree = DecisionTreeClassifier(max_depth=None, max_features=None, min_samples_leaf=1)
    clf_tree.fit(x_train, y_train) # Обучаем модель
    y_tree_pred = clf_tree.predict(x_test)

    svc_rsc = recall_score(y_test, y_svc_pred)
    nbrs_rsc = recall_score(y_test, y_knbrs_pred)
    tree_rsc = recall_score(y_test, y_tree_pred)

    return f'Метод опорных векторов: {svc_rsc}. Метод k-ближайших соседей: {nbrs_rsc}. Деревья решений: {tree_rsc}.'


X, Y = table_preprocessing ('hotel_reservations.csv')
hotel_booking_analyze (X, Y)
# Out:
# 'Метод опорных векторов: 0.9347112860892388. Метод k-ближайших соседей: 0.895505249343832. Деревья решений: 0.9045275590551181.'
